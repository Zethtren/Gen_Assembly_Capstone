# %% [markdown]
# ### Sectioning DataFrames:
#
# Using the ful size DataFrame gave me a ton of crashing errors so

# %%
import pandas as pd

# %%
df = pd.read_csv('./Directories/Train_finished.csv')

# %%
df.drop(['Sentece', 'Sentences_Fixed', 'Sentence_Characters'], axis=1, inplace=True)

# %%
df
# Out:
#                                                      File  \
# 0       /home/houston/Desktop/General_Assembly/CapSton...
# 1       /home/houston/Desktop/General_Assembly/CapSton...
# 2       /home/houston/Desktop/General_Assembly/CapSton...
# 3       /home/houston/Desktop/General_Assembly/CapSton...
# 4       /home/houston/Desktop/General_Assembly/CapSton...
# ...                                                   ...
# 257854  /home/houston/Desktop/General_Assembly/CapSton...
# 257855  /home/houston/Desktop/General_Assembly/CapSton...
# 257856  /home/houston/Desktop/General_Assembly/CapSton...
# 257857  /home/houston/Desktop/General_Assembly/CapSton...
# 257858  /home/houston/Desktop/General_Assembly/CapSton...
#
#                                          Character_Labels
# 0       ['G', 'O', 'O', 'D', ' ', 'M', 'E', 'N', ' ', ...
# 1       ['A', 'N', 'D', ' ', 'L', 'I', 'V', 'E', 'D', ...
# 2       ['W', 'I', 'T', 'H', ' ', 'T', 'H', 'E', ' ', ...
# ...

# %%
for i in range(1008):
    
    df_temp = df[i*256:(i+1)*256]
    df_temp.to_csv(f'./Directories/Train/Train{i}_pre.csv', index=False)

# %%
df = pd.read_csv('./Directories/Test_finished.csv')
df.drop(['Sentece', 'Sentences_Fixed', 'Sentence_Characters'], axis=1, inplace=True)
df
# Out:
#                                                    File  \
# 0     /home/houston/Desktop/General_Assembly/CapSton...
# 1     /home/houston/Desktop/General_Assembly/CapSton...
# 2     /home/houston/Desktop/General_Assembly/CapSton...
# 3     /home/houston/Desktop/General_Assembly/CapSton...
# 4     /home/houston/Desktop/General_Assembly/CapSton...
# ...                                                 ...
# 5554  /home/houston/Desktop/General_Assembly/CapSton...
# 5555  /home/houston/Desktop/General_Assembly/CapSton...
# 5556  /home/houston/Desktop/General_Assembly/CapSton...
# 5557  /home/houston/Desktop/General_Assembly/CapSton...
# 5558  /home/houston/Desktop/General_Assembly/CapSton...
#
#                                        Character_Labels
# 0     ['T', 'H', 'E', ' ', 'A', 'N', 'A', 'L', 'Y', ...
# 1     ['W', 'H', 'A', 'T', ' ', 'I', 'S', ' ', 'C', ...
# 2     ['W', 'H', 'E', 'T', 'H', 'E', 'R', ' ', 'O', ...
# 3     ['A', 'N', 'D', ' ', 'W', 'H', 'A', 'T', ' ', ...
# ...

# %%
for i in range(22):
    
    df_temp = df[i*256:(i+1)*256]
    df_temp.to_csv(f'./Directories/Test/Test{i}_pre.csv', index=False)

# %%
df = pd.read_csv('./Directories/Dev_finished.csv')
df.drop(['Sentece', 'Sentences_Fixed', 'Sentence_Characters'], axis=1, inplace=True)
df
# Out:
#                                                    File  \
# 0     /home/houston/Desktop/General_Assembly/CapSton...
# 1     /home/houston/Desktop/General_Assembly/CapSton...
# 2     /home/houston/Desktop/General_Assembly/CapSton...
# 3     /home/houston/Desktop/General_Assembly/CapSton...
# 4     /home/houston/Desktop/General_Assembly/CapSton...
# ...                                                 ...
# 5562  /home/houston/Desktop/General_Assembly/CapSton...
# 5563  /home/houston/Desktop/General_Assembly/CapSton...
# 5564  /home/houston/Desktop/General_Assembly/CapSton...
# 5565  /home/houston/Desktop/General_Assembly/CapSton...
# 5566  /home/houston/Desktop/General_Assembly/CapSton...
#
#                                        Character_Labels
# 0     ['A', ' ', 'M', 'A', 'N', ' ', 'S', 'A', 'I', ...
# 1     ['S', 'W', 'E', 'A', 'T', ' ', 'C', 'O', 'V', ...
# 2     ['T', 'H', 'E', ' ', 'C', 'U', 'T', ' ', 'O', ...
# 3     ['H', 'I', 'S', ' ', 'I', 'N', 'S', 'T', 'A', ...
# ...

# %%
for i in range(22):
    
    df_temp = df[i*256:(i+1)*256]
    df_temp.to_csv(f'./Directories/Dev/Dev{i}_pre.csv', index=False)
